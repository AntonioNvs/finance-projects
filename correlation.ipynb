# %% [markdown]
# ## Análise de correlação entre ativos
#
# O objetivo aqui é, dado o desempenho histórico de ativos em um ano, verificar quais são mais correlacionados com os outros.

# %%
# Ativos presentes na minha carteira
papers = ["VALE3.SA", "B3SA3.SA", "GGBR4.SA", "TASA4.SA", "CMIG4.SA", "TAEE11.SA", "SLCE3.SA"]

# %%
import pandas as pd
import yfinance as yf

# Get the historical data for each paper
historical_data = {}
for paper in papers:
    data = yf.download(paper, start='2023-01-01', end='2024-01-01')["Adj Close"]
    historical_data[paper] = data

df = pd.DataFrame(historical_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlação entre ativos da minha carteira em 2023')
plt.show()
